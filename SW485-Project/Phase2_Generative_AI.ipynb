# %% [markdown]
# # Phase 2 - Part B: Generative AI Integration
#
# ## 1. Generative AI Model Setup
#
# We use **LLaMA 3.3 70B** (Meta's open-source LLM) accessed through the **Groq API**.
#
# **Why Groq + LLaMA?**
# - Free API access (no credit card required)
# - Open-source model aligns with academic transparency
# - Fast inference via Groq's specialized hardware
# - Listed as an option in the project handbook

# %%
# Import required libraries
import os
from dotenv import load_dotenv
from groq import Groq

# Load API key from .env file
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

# Initialize the Groq client
client = Groq(api_key=api_key)

# Model configuration
MODEL_NAME = "llama-3.3-70b-versatile"

# Quick connection test
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[{"role": "user", "content": "Reply with: connection OK"}],
    max_tokens=10
)

print("Model:", MODEL_NAME)
print("Response:", response.choices[0].message.content)
# Out:
# Model: llama-3.3-70b-versatile
# Response: connection OK

# %% [markdown]
# ## 2. Prompt Template Design
#
# ### Template 1: Simple Explanation
#
# **Goal:** Explain the prediction to the patient in plain, friendly language.
#
# **Target user:** Patients with no medical background.
#
# **Design choice:** Short response (3-5 sentences), no medical jargon, reassuring tone.

# %%
# Template 1: Simple Explanation
# Goal: explain results in plain language for non-medical users

template_1_system = """You are a friendly health assistant. 
Explain medical results in simple, everyday language. 
Avoid technical terms. Keep responses short (3-5 sentences).
Be reassuring but honest."""

template_1_user = """A patient received their liver health screening result.

Prediction: {prediction}
Key values:
{features}

Explain this result in plain language, as if talking to a friend with no medical background.
Focus on the overall meaning, not the numbers."""

# %%
def simple_explanation(prediction, features):
    """Generate a simple explanation using Template 1."""
    
    user_message = template_1_user.format(
        prediction=prediction,
        features=features
    )
    
    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": template_1_system},
            {"role": "user", "content": user_message}
        ],
        temperature=0.7,
        max_tokens=300
    )
    
    return response.choices[0].message.content

# %%
import pandas as pd

# Load raw dataset (easier for the AI to interpret)
data = pd.read_csv("Raw_Dataset/indian_liver_patient.csv")

# 3 diverse test cases
test_indices = [0, 315, 440] 

for i, idx in enumerate(test_indices, start=1):
    patient = data.iloc[idx]
    
    # Convert prediction: 1 = Liver Disease, 2 = No Liver Disease
    prediction = "Liver Disease Detected" if patient["Dataset"] == 1 else "No Liver Disease"
    
    # Format features (drop the label so the AI doesn't see the answer)
    features = "\n".join([
        f"- {col}: {val}"
        for col, val in patient.drop("Dataset").items()
    ])
    
    # Generate explanation
    print(f"Patient {i}: (row {idx}), Prediction: {prediction}")
    
    result = simple_explanation(prediction, features)
    print(result)
# Out:
# Patient 1: (row 0), Prediction: Liver Disease Detected
# Hey, I know it can be scary to get screening results, but let's break it down. Unfortunately, the test suggests that there might be some issues with your liver. The good news is that we caught it, and now we can work on figuring out what's going on and how to take care of it. It's likely that you'll need to have some more tests or talk to a doctor to get a better understanding of what's happening and what you can do to get your liver healthy again.
# Patient 2: (row 315), Prediction: No Liver Disease
# Hey, great news - your liver health screening results look good. The test didn't find any signs of liver disease, which is a big relief. This means your liver is working properly and you don't have to worry about any serious issues right now. Just keep taking care of yourself and you'll be fine. Overall, it's a positive result, so you can breathe easy.
# Patient 3: (row 440), Prediction: Liver Disease Detected
# Hey, I know it can be scary to get a health screening result like this, but let's break it down. Unfortunately, the test suggests that there might be some issues with your liver. This doesn't necessarily mean it's serious, but it's a sign that we should look into it further. It's like a warning sign that something might be off, and we can work together to figure out what's going on and get you the care you need.

# %% [markdown]
# ### Template 4: Step-by-Step Guide
#
# **Goal:** Walk through each lab value one by one to explain why the model made its prediction.
#
# **Target user:** Patients who want to understand their result in detail, and doctors who need a transparent review of the reasoning.
#
# **Design choice:** Step-by-step breakdown of each biomarker against its normal range, followed by a reasoning conclusion that ties everything together.

# %%
# Template 4: Step-by-Step Guide
# Goal: walk through each lab value and explain the reasoning behind the prediction

template_4_system = """You are a medical reasoning assistant.
When given lab values and a prediction, think step by step:
1. Check each value against its normal range.
2. Note which ones are too high, too low, or normal.
3. Explain how the abnormal values connect to the prediction.
4. End with a short conclusion that ties everything together.
Keep your language clear and use the reference ranges as part of your reasoning."""

template_4_user = """A machine learning model made the following prediction for a liver patient.

Prediction: {prediction}
Lab Values:
{features}

Go through each lab value step by step and explain whether it supports
or goes against the prediction. End with a clear reasoning conclusion."""

# %%
def step_by_step_guide(prediction, features):
    """Generate a step-by-step reasoning analysis using Template 4."""

    user_message = template_4_user.format(
        prediction=prediction,
        features=features
    )

    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": template_4_system},
            {"role": "user", "content": user_message}
        ],
        temperature=0.3,
        max_tokens=600
    )

    return response.choices[0].message.content

# %%
# Test Template 4 0n 3 test cases

for i, idx in enumerate(test_indices, start=1):
    patient = data.iloc[idx]

    prediction = "Liver Disease Detected" if patient["Dataset"] == 1 else "No Liver Disease"

    features = "\n".join([
        f"- {col}: {val}"
        for col, val in patient.drop("Dataset").items()
    ])

    print(f"Patient {i}: (row {idx}), Prediction: {prediction}")

    result = step_by_step_guide(prediction, features)
    print(result)
# Out:
# Patient 1: (row 0), Prediction: Liver Disease Detected
# To evaluate the prediction of "Liver Disease Detected," let's examine each lab value against its normal range and see how it supports or contradicts the prediction.
#
# 1. **Age: 65** - Age itself is not a lab value but a demographic factor. However, it's known that the risk of liver disease can increase with age. Thus, being 65 might slightly increase the likelihood of liver disease, but it's not a direct indicator.
#
# 2. **Gender: Female** - Like age, gender is a demographic factor and not a lab value. Some liver diseases have different prevalence rates among genders, but without specific context, it's hard to draw a direct connection to the prediction.
#
# 3. **Total_Bilirubin: 0.7** - The normal range for total bilirubin is approximately 0.1 to 1.2 mg/dL. With a value of 0.7, this falls within the normal range. Normal bilirubin levels do not typically indicate liver disease, so this value does not support the prediction.
#
# 4. **Direct_Bilirubin: 0.1** - The normal range for direct bilirubin is about 0.0 to 0.3 mg/dL. A value of 0.1 is within the normal range. Like total bilirubin, normal direct bilirubin levels do not suggest liver disease, so this value also does not support the prediction.
#
# 5. **Alkaline_Phosphotase: 187** - The normal range for alkaline phosphatase (ALP) is roughly 30 to 120 U/L. A value of 187 is elevated, which can indicate liver disease, among other conditions like bone disorders. Elevated ALP levels can suggest cholestasis or bone-related issues, so this value supports the prediction of liver disease.
#
# 6. **Alamine_Aminotransferase (ALT): 16** - The normal range for ALT is approximately 0 to 40 U/L. With a value of 16, this falls within the normal range. Normal ALT levels are not indicative of liver disease, so this value does not support the prediction.
#
# 7. **Aspartate_Aminotransferase (AST): 18** - The normal range for AST is roughly 0 to 40 U/L. A value of 18 is within the normal range. Like ALT, normal AST levels do not suggest liver disease, so this value also does not support the prediction.
#
# 8. **Total_Proteins: 6.8** - The normal range for total proteins is about 6 to 8.3 g/dL. With a value of 6.8, this falls within the normal range. Normal total protein levels do not specifically indicate liver disease, so this value does not strongly support or refute the prediction.
#
# 9. **Albumin: 3.3** - The normal range for albumin is
# Patient 2: (row 315), Prediction: No Liver Disease
# To assess the prediction of "No Liver Disease" made by the machine learning model, let's evaluate each lab value against its normal range and determine how it supports or contradicts the prediction.
#
# 1. **Age: 22** - Age itself is not a direct indicator of liver disease, but younger individuals are generally less likely to have liver disease than older adults. This value does not directly support or contradict the prediction but is a demographic factor.
#
# 2. **Gender: Male** - Like age, gender is a demographic factor and does not directly indicate liver health. However, some liver conditions may have a gender predilection, but this is not relevant without more specific context.
#
# 3. **Total_Bilirubin: 0.9** - The normal range for total bilirubin is approximately 0.1 to 1.2 mg/dL. With a value of 0.9, this falls within the normal range, supporting the prediction of no liver disease, as elevated bilirubin levels can indicate liver dysfunction or disease.
#
# 4. **Direct_Bilirubin: 0.3** - The normal range for direct (conjugated) bilirubin is typically less than 0.3 mg/dL. A value of 0.3 is at the upper limit of normal, which does not strongly contradict the prediction but warrants attention, as slightly elevated direct bilirubin can be seen in certain liver conditions.
#
# 5. **Alkaline_Phosphotase: 179** - The normal range for alkaline phosphatase (ALP) is approximately 30 to 120 U/L. A value of 179 is elevated, suggesting bone or liver involvement. Elevated ALP can indicate liver disease, among other conditions, which contradicts the prediction of no liver disease.
#
# 6. **Alamine_Aminotransferase (ALT): 18** - The normal range for ALT is typically 0 to 40 U/L. With a value of 18, this falls within the normal range, supporting the prediction of no liver disease, as elevated ALT levels can indicate liver cell injury.
#
# 7. **Aspartate_Aminotransferase (AST): 21** - The normal range for AST is approximately 0 to 40 U/L. A value of 21 is within the normal range, supporting the prediction, as elevated AST levels can indicate liver cell injury.
#
# 8. **Total_Proteins: 6.7** - The normal range for total proteins is approximately 6 to 8.3 g/dL. With a value of 6.7, this falls within the normal range, which neither strongly supports nor contradicts the prediction, as total protein levels can be influenced by various factors.
#
# 9. **Albumin: 3.7** - The normal range for albumin is approximately 3.5 to 5 g/dL. A value of 3.7 is within
# Patient 3: (row 440), Prediction: Liver Disease Detected
# To assess the prediction of "Liver Disease Detected," let's evaluate each lab value against its normal range and determine how it supports or contradicts the prediction.
#
# 1. **Age: 49** - Age itself is not a lab value but a demographic factor. However, liver disease can occur at any age, so this does not directly support or contradict the prediction.
#
# 2. **Gender: Female** - Like age, gender is a demographic factor and does not directly influence the prediction of liver disease.
#
# 3. **Total_Bilirubin: 0.8** - The normal range for total bilirubin is typically 0.1-1.2 mg/dL. With a value of 0.8, this falls within the normal range. **Normal** - This does not support the prediction of liver disease, as elevated bilirubin levels are often associated with liver dysfunction.
#
# 4. **Direct_Bilirubin: 0.2** - The normal range for direct bilirubin is usually 0.0-0.3 mg/dL. A value of 0.2 is within the normal range. **Normal** - Similar to total bilirubin, this does not support the prediction of liver disease.
#
# 5. **Alkaline_Phosphotase: 198** - The normal range for alkaline phosphatase (ALP) is approximately 30-120 U/L. A value of 198 is **elevated**. Elevated ALP levels can indicate liver disease, among other conditions like bone disorders. This supports the prediction.
#
# 6. **Alamine_Aminotransferase (ALT): 23** - The normal range for ALT is about 0-40 U/L. With a value of 23, this is **within the normal range**. Elevated ALT levels are often associated with liver damage, so a normal value does not support the prediction of liver disease.
#
# 7. **Aspartate_Aminotransferase (AST): 20** - The normal range for AST is approximately 0-40 U/L. A value of 20 is **within the normal range**. Like ALT, elevated AST levels can indicate liver damage, so a normal value does not support the prediction.
#
# 8. **Total_Proteins: 7.0** - The normal range for total proteins is about 6-8.3 g/dL. A value of 7.0 is **within the normal range**. This does not specifically support or contradict the prediction, as total protein levels can be influenced by many factors.
#
# 9. **Albumin: 4.3** - The normal range for albumin is approximately 3.5-5.5 g/dL. With a value of 4.3, this is **within the normal range**. Low albumin levels can indicate liver disease, among other conditions, so a normal value does not support the prediction.
